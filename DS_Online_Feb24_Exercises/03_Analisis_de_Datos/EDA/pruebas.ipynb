# %%
import pandas as pd
from bs4 import BeautifulSoup 
import requests
import pprint 
from func import *

# %%
df = pd.read_csv('./data/SP1.csv')
df.head()
# Out:
#    Div        Date   Time    HomeTeam     AwayTeam  FTHG  FTAG FTR  HTHG  \
# 0  SP1  11/08/2023  18:30     Almeria    Vallecano     0     2   A     0
# 1  SP1  11/08/2023  21:00     Sevilla     Valencia     1     2   A     0
# 2  SP1  12/08/2023  16:00    Sociedad       Girona     1     1   D     1
# 3  SP1  12/08/2023  18:30  Las Palmas     Mallorca     1     1   D     1
# 4  SP1  12/08/2023  20:30  Ath Bilbao  Real Madrid     0     2   A     0
#
#    HTAG  ... AvgC<2.5  AHCh  B365CAHH  B365CAHA  PCAHH  PCAHA  MaxCAHH  \
# 0     2  ...     1.64  0.00      1.85      2.08   1.86   2.07     1.91
# 1     0  ...     1.61 -0.50      1.94      1.99   1.94   1.98     1.96
# 2     0  ...     1.72 -0.75      2.05      1.75   2.10   1.82     2.14
# 3     0  ...     1.40 -0.25      2.18      1.77   2.20   1.77     2.21
# 4     2  ...     1.89  0.25      1.99      1.94   1.99   1.93     2.10
#
#    MaxCAHA  AvgCAHH  AvgCAHA
# 0     2.09     1.86     2.01
# 1     2.00     1.93     1.94
# ...

# %%
url_plantilla_madrid="https://www.transfermarkt.es/real-madrid-cf/kader/verein/418/plus/0/galerie/0?saison_id=2022"

# %%
soup=get_soup(url_plantilla_madrid)

# %%
df=crear_df(soup)

# %%
df
# Out:
#                  Nombre Edad              Posición          Nacionalidad  \
# 0      Thibaut Courtois   31               Portero               Bélgica
# 1          Andriy Lunin   24               Portero               Ucrania
# 2         Mario de Luis   21               Portero                España
# 3            Luis López   22               Portero                España
# 4       Lucas Cañizares   21               Portero                España
# 5         Diego Piñeiro   19               Portero                España
# 6         Fran González   18               Portero                España
# 7          Éder Militão   25       Defensa central                Brasil
# 8           David Alaba   31       Defensa central               Austria
# 9       Antonio Rüdiger   30       Defensa central              Alemania
# 10      Nacho Fernández   33       Defensa central                España
# 11        Jesús Vallejo   26       Defensa central                España
# ...
